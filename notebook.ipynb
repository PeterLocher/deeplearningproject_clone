# %%
import training

training.train_km_unet(32, 32, 8, img_size=1024, num_classes=6, prefix="multi_class", skip=False)

# %%
from experiments import show_predictions_by_epoch, one_hot_to_rgb, one_hot_to_rgb_single_class, show_feature_maps, load_model, test_model
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from experiments import show_predictions_by_epoch, one_hot_to_rgb, one_hot_to_rgb_single_class, show_feature_maps, load_model, test_model
#
# File ~\PycharmProjects\deeplearningproject\experiments.py:174
#     172 show_predictions_by_epoch("models_256_china_road_v2_3_models/conv1", c=3, seed=seed, fcolor=one_hot_to_rgb_single_class)
#     173 show_predictions_by_epoch("models_256_china_road_v2_3_models/conv2", c=3, seed=seed, fcolor=one_hot_to_rgb_single_class)
# --> 174 show_predictions_by_epoch("models_256_china_road_v2_3_models/kar_no_drop", c=3, seed=seed, fcolor=one_hot_to_rgb_single_class)
#     176 show_predictions_by_epoch("models_256_china_multi_class/conv1", c=-1, seed=seed, fcolor=one_hot_to_rgb)
#     177 show_predictions_by_epoch("models_256_china_multi_class/conv2", c=-1, seed=seed, fcolor=one_hot_to_rgb)
#
# File ~\PycharmProjects\deeplearningproject\experiments.py:84, in show_predictions_by_epoch(folder, samples, c, seed, figsize, fcolor)
#      82 for col, file_name in enumerate(model_files):
#      83     print(file_name)
# ---> 84     model = load_model(folder + "/" + file_name)
#      85     out = model.predict(image_test)
#      86     pred_images = fcolor(out)
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\keras\saving\save.py:209, in load_model(filepath, custom_objects, compile, options)
#     206   raise IOError(f'No file or directory found at {filepath_str}')
#     208 if tf.io.gfile.isdir(filepath_str):
# --> 209   return saved_model_load.load(filepath_str, compile, options)
#     210 else:
#     211   if h5py is None:
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\keras\saving\saved_model\load.py:141, in load(path, compile, options)
#     139 for node_id, loaded_node in keras_loader.loaded_nodes.items():
#     140   nodes_to_load[keras_loader.get_path(node_id)] = loaded_node
# --> 141 loaded = tf.__internal__.saved_model.load_partial(
#     142     path, nodes_to_load, options=options)
#     144 # Finalize the loaded layers and remove the extra tracked dependencies.
#     145 keras_loader.finalize_objects()
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\tensorflow\python\saved_model\load.py:912, in load_partial(export_dir, filters, tags, options)
#     910 with ops.init_scope():
#     911   try:
# --> 912     loader = Loader(object_graph_proto, saved_model_proto, export_dir,
#     913                     ckpt_options, options, filters)
#     914   except errors.NotFoundError as err:
#     915     raise FileNotFoundError(
#     916         str(err) + "\n You may be trying to load on a different device "
#     917         "from the computational device. Consider setting the "
#     918         "`experimental_io_device` option in `tf.saved_model.LoadOptions` "
#     919         "to the io_device such as '/job:localhost'.")
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\tensorflow\python\saved_model\load.py:151, in Loader.__init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, save_options, filters)
#     148 self._proto = object_graph_proto
#     149 self._export_dir = export_dir
#     150 self._concrete_functions = (
# --> 151     function_deserialization.load_function_def_library(
#     152         library=meta_graph.graph_def.library,
#     153         saved_object_graph=self._proto,
#     154         wrapper_function=_WrapperFunction))
#     155 # Store a set of all concrete functions that have been set up with
#     156 # captures.
#     157 self._restored_concrete_functions = set()
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\tensorflow\python\saved_model\function_deserialization.py:409, in load_function_def_library(library, saved_object_graph, load_shared_name_suffix, wrapper_function)
#     403 # There is no need to copy all functions into the function def graph. It
#     404 # leads to a O(n^2) increase of memory when importing functions and the
#     405 # extra function definitions are a no-op since they already imported as a
#     406 # function before and passed in explicitly (due to the topologic sort
#     407 # import).
#     408 with graph.as_default():
# --> 409   func_graph = function_def_lib.function_def_to_graph(
#     410       fdef,
#     411       structured_input_signature=structured_input_signature,
#     412       structured_outputs=structured_outputs)
#     413 # Restores gradients for function-call ops (not the same as ops that use
#     414 # custom gradients)
#     415 _restore_gradient_functions(func_graph, renamed_functions, loaded_gradients)
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\tensorflow\python\framework\function_def_to_graph.py:123, in function_def_to_graph(fdef, structured_input_signature, structured_outputs, input_shapes)
#     118     # _output_shapes for functions can sometimes be too long because the
#     119     # output-intermediates-for-gradients version of the function was
#     120     # substituted before saving. We'll accept that here. (See b/133666530).
#     121     for output_index, shape in enumerate(
#     122         output_shapes.list.shape[:len(op.outputs)]):
# --> 123       op.outputs[output_index].set_shape(shape)
#     124 output_names = {}
#     125 for ret_arg_def, tensor_name in zip(
#     126     fdef.signature.output_arg, output_tensor_names):
#
# File ~\anaconda3\envs\threeeight\lib\site-packages\tensorflow\python\framework\ops.py:829, in Tensor.set_shape(self, shape)
#     827       dim_list.append(dim.value)
#     828 try:
# --> 829   pywrap_tf_session.TF_GraphSetTensorShape_wrapper(
#     830       self._op._graph._c_graph,  # pylint: disable=protected-access
#     831       self._as_tf_output(),
#     832       dim_list,
#     833       unknown_shape)
#     834 except errors.InvalidArgumentError as e:
#     835   # Convert to ValueError for backwards compatibility.
#     836   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
seed=1
show_predictions_by_epoch("models_256_china_road_v2_3_models/conv1", c=3, seed=seed, fcolor=one_hot_to_rgb_single_class)
show_predictions_by_epoch("models_256_china_road_v2_3_models/conv2", c=3, seed=seed, fcolor=one_hot_to_rgb_single_class)
show_predictions_by_epoch("models_256_china_road_v2_3_models/kar_no_drop", c=3, seed=seed, fcolor=one_hot_to_rgb_single_class)

# %%
show_predictions_by_epoch("models_256_china_multi_class/conv1", c=-1, seed=seed, fcolor=one_hot_to_rgb)
show_predictions_by_epoch("models_256_china_multi_class/conv2", c=-1, seed=seed, fcolor=one_hot_to_rgb)
show_predictions_by_epoch("models_256_china_multi_class/kar", c=-1, seed=seed, fcolor=one_hot_to_rgb)

# %%
image_number = 4
show_feature_maps(load_model("models_256_china_road_v2_3_models/kar/kar_mse_road_skip_china_3200_100_8"), image_number=image_number)
show_feature_maps(load_model("models_256_china_road_v2_3_models/kar/kar_mse_road_skip_china_6400_200_8"), image_number=image_number)
show_feature_maps(load_model("models_256_china_multi_class/kar/kar_mse_multi_class_skip_china_32_100_8"), image_number=image_number)
show_feature_maps(load_model("models_256_china_multi_class/kar/kar_mse_multi_class_skip_china_32_400_8"), image_number=image_number)
show_feature_maps(load_model("models_256_china_multi_class/conv2/my_unet_mse_multi_class_skip_china_32_100_8"), image_number=image_number)
show_feature_maps(load_model("models_256_china_multi_class/conv2/my_unet_mse_multi_class_skip_china_32_400_8"), image_number=image_number)

# %%
#Metrics
test_model(load_model("models_poland_1024_multiclass/conv2/my_unet_mse_multi_class_conv2_poland_48_8_1536"), single_class=-1)
test_model(load_model("models_poland_1024_multiclass/conv1/my_unet_mse_multi_class_poland_48_8_1536"), single_class=-1)
test_model(load_model("models_256_china_multi_class/kar/kar_mse_multi_class_skip_china_32_400_8"), single_class=-1)
